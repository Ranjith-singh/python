# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s.describe()
# Out:
# count    5.000000
# mean     4.600000
# std      2.701851
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      6.000000
# max      8.000000
# dtype: float64

# %%
dates= pd.date_range("20250302", periods=6)
print(dates)
df= pd.DataFrame(np.random.randn(6,4), index=dates)
df
# Out:
# DatetimeIndex(['2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05',
#                '2025-03-06', '2025-03-07'],
#               dtype='datetime64[ns]', freq='D')
#                    0         1         2         3
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773
# 2025-03-06  0.343023 -1.549563  1.153794  0.680148
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(list(range(10,14)), index=list(range(4)), dtype="float32"),
        "D": np.array([3,2] * 2, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B     C  D      E    F
# 0  1.0 2013-01-02  10.0  3   test  foo
# 1  1.0 2013-01-02  11.0  2  train  foo
# 2  1.0 2013-01-02  12.0  3   test  foo
# 3  1.0 2013-01-02  13.0  2  train  foo

# %%
print(df.head(2))
print(df.tail(2))
# Out:
#                    A         B         C         D
# 2001-01-02 -1.702012  0.935134  0.645911 -0.761003
# 2001-01-03  0.396420  0.196036  0.476368 -0.995650
#                    A         B         C         D
# 2001-01-06 -0.550551 -0.454244 -1.291258 -1.925024
# 2001-01-07 -1.018586  1.395712  0.471119  2.357871

# %%
print(df.index)
print(df.columns)
# Out:
# DatetimeIndex(['2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05',
#                '2025-03-06', '2025-03-07'],
#               dtype='datetime64[ns]', freq='D')
# RangeIndex(start=0, stop=4, step=1)

# %%
df.to_numpy()
# Out:
# array([[-1.18400717, -0.64220158, -0.85432019, -1.00915009],
#        [-0.42433146, -0.37430599, -0.08813533, -0.18127638],
#        [-2.32054308, -0.11222519, -0.45006179, -0.82773345],
#        [ 1.35119237,  1.09037063, -0.67175588, -1.13077306],
#        [ 0.34302291, -1.54956341,  1.15379406,  0.68014772],
#        [ 0.78511529, -2.00530047, -0.28347309, -0.02772362]])

# %%
print(pd.DataFrame(df.to_numpy()))
print(pd.DataFrame(df.to_numpy().reshape(4, 6)))
# Out:
#           0         1         2         3
# 0 -1.184007 -0.642202 -0.854320 -1.009150
# 1 -0.424331 -0.374306 -0.088135 -0.181276
# 2 -2.320543 -0.112225 -0.450062 -0.827733
# 3  1.351192  1.090371 -0.671756 -1.130773
# 4  0.343023 -1.549563  1.153794  0.680148
# 5  0.785115 -2.005300 -0.283473 -0.027724
#           0         1         2         3         4         5
# 0 -1.184007 -0.642202 -0.854320 -1.009150 -0.424331 -0.374306
# 1 -0.088135 -0.181276 -2.320543 -0.112225 -0.450062 -0.827733
# 2  1.351192  1.090371 -0.671756 -1.130773  0.343023 -1.549563
# 3  1.153794  0.680148  0.785115 -2.005300 -0.283473 -0.027724

# %%
df.describe()
# Out:
#               0         1         2         3
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.241592 -0.598871 -0.198992 -0.416085
# std    1.354728  1.097682  0.716303  0.698519
# min   -2.320543 -2.005300 -0.854320 -1.130773
# 25%   -0.994088 -1.322723 -0.616332 -0.963796
# 50%   -0.040654 -0.508254 -0.366767 -0.504505
# 75%    0.674592 -0.177745 -0.136970 -0.066112
# max    1.351192  1.090371  1.153794  0.680148

# %%
df.T
# Out:
#    2025-03-02  2025-03-03  2025-03-04  2025-03-05  2025-03-06  2025-03-07
# 0   -1.184007   -0.424331   -2.320543    1.351192    0.343023    0.785115
# 1   -0.642202   -0.374306   -0.112225    1.090371   -1.549563   -2.005300
# 2   -0.854320   -0.088135   -0.450062   -0.671756    1.153794   -0.283473
# 3   -1.009150   -0.181276   -0.827733   -1.130773    0.680148   -0.027724

# %%
print(df.sort_index(axis=0,ascending=False))
print(df.sort_index(axis=1, ascending=False))
# Out:
#                    0         1         2         3
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724
# 2025-03-06  0.343023 -1.549563  1.153794  0.680148
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150
#                    3         2         1         0
# 2025-03-02 -1.009150 -0.854320 -0.642202 -1.184007
# 2025-03-03 -0.181276 -0.088135 -0.374306 -0.424331
# 2025-03-04 -0.827733 -0.450062 -0.112225 -2.320543
# 2025-03-05 -1.130773 -0.671756  1.090371  1.351192
# 2025-03-06  0.680148  1.153794 -1.549563  0.343023
# 2025-03-07 -0.027724 -0.283473 -2.005300  0.785115

# %%
df2.sort_values(by="B")
# Out:
#      A          B     C  D      E    F
# 0  1.0 2013-01-02  10.0  3   test  foo
# 1  1.0 2013-01-02  11.0  2  train  foo
# 2  1.0 2013-01-02  12.0  3   test  foo
# 3  1.0 2013-01-02  13.0  2  train  foo

# %%
df1= df.T
df1.sort_values(by="20250307",ascending=False)
# Out:
#    2025-03-02  2025-03-03  2025-03-04  2025-03-05  2025-03-06  2025-03-07
# 0   -1.184007   -0.424331   -2.320543    1.351192    0.343023    0.785115
# 3   -1.009150   -0.181276   -0.827733   -1.130773    0.680148   -0.027724
# 2   -0.854320   -0.088135   -0.450062   -0.671756    1.153794   -0.283473
# 1   -0.642202   -0.374306   -0.112225    1.090371   -1.549563   -2.005300

# %%
df[1]
# Out:
# 2025-03-02   -0.642202
# 2025-03-03   -0.374306
# 2025-03-04   -0.112225
# 2025-03-05    1.090371
# 2025-03-06   -1.549563
# 2025-03-07   -2.005300
# Freq: D, Name: 1, dtype: float64

# %%
df[0:4:2]
# Out:
#                    0         1         2         3
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733

# %%
print(df["20250302":"20250306":2])
# Out:
#                    A         B         C         D  F
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150  0
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733  2
# 2025-03-06  0.343023  2.000000  1.153794  0.680148  4

# %%
df.loc[dates[0]]
# Out:
# 0   -1.184007
# 1   -0.642202
# 2   -0.854320
# 3   -1.009150
# Name: 2025-03-02 00:00:00, dtype: float64

# %%
df.columns= list("ABCD")
df.loc[:,list("AB")]
# Out:
#                    A         B
# 2025-03-02 -1.184007 -0.642202
# 2025-03-03 -0.424331 -0.374306
# 2025-03-04 -2.320543 -0.112225
# 2025-03-05  1.351192  1.090371
# 2025-03-06  0.343023 -1.549563
# 2025-03-07  0.785115 -2.005300

# %%
print(df.loc[dates[0],"A"])
# Out:
# -1.1840071721405434

# %%
df.iloc[3]
# Out:
# A   -0.311370
# B   -0.213647
# C   -2.078210
# D    2.000391
# Name: 2001-01-05 00:00:00, dtype: float64

# %%
print(df.iloc[0:5,0:2])
print(df.iloc[0:5:2,0:4:2])
# Out:
#                    A         B
# 2025-03-02 -1.184007 -0.642202
# 2025-03-03 -0.424331 -0.374306
# 2025-03-04 -2.320543 -0.112225
# 2025-03-05  1.351192  1.090371
# 2025-03-06  0.343023 -1.549563
#                    A         C
# 2025-03-02 -1.184007 -0.854320
# 2025-03-04 -2.320543 -0.450062
# 2025-03-06  0.343023  1.153794

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2001-01-03 -0.603252  0.555889
# 2001-01-04 -0.697640 -0.534425
# 2001-01-06  0.885305  0.588951

# %%
df.iloc[0,0]
# Out:
# np.float64(0.8099620811348688)

# %%
print(df["A"]>0)
df[df["A"]>0]
# Out:
# 2025-03-02    False
# 2025-03-03    False
# 2025-03-04    False
# 2025-03-05     True
# 2025-03-06     True
# 2025-03-07     True
# Freq: D, Name: A, dtype: bool
#                    A         B         C         D
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773
# 2025-03-06  0.343023 -1.549563  1.153794  0.680148
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724

# %%
df.iloc[4,1]= 2.00
df[df>0].dropna()
# Out:
#                    A    B         C         D
# 2025-03-06  0.343023  2.0  1.153794  0.680148

# %%
print(df.count().iloc[0])
print(df.loc['20250306'])
print(df.loc[pd.Timestamp("20250306")].sum())
# Out:
# 6
# A    0.343023
# B    2.000000
# C    1.153794
# D    0.680148
# Name: 2025-03-06 00:00:00, dtype: float64
# 4.176964696041798

# %%
df2=df.copy()
df2['E']=["one","one","two","three","four","five"]
df2
# Out:
#                    A         B         C         D      E
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150    one
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276    one
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733    two
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773  three
# 2025-03-06  0.343023  2.000000  1.153794  0.680148   four
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724   five

# %%
print(df2[df2["E"].isin(["one"])])
print(df2[~df2["E"].isin(['one'])])
# Out:
#                    A         B         C         D    E
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150  one
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276  one
#                    A         B         C         D      E
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733    two
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773  three
# 2025-03-06  0.343023  2.000000  1.153794  0.680148   four
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724   five

# %%
df2[~df2["E"].isin(["one"])]
df2[df2["E"].isin(["one"])==False]
# Out:
#                    A         B         C         D      E
# 2001-01-04 -0.492466 -1.113067 -1.032611 -1.555697    two
# 2001-01-05 -2.001224  0.887376  0.278983  1.001370  three
# 2001-01-06 -1.071654  0.081201 -0.766555 -1.199528   four
# 2001-01-07  0.164797 -0.955284  0.003420  0.198967   five

# %%
s1 = pd.Series(list(range(6)),index=pd.date_range("20250302",periods=6))
df["F"]=s1
df
# Out:
#                    A         B         C         D  F
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150  0
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276  1
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733  2
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773  3
# 2025-03-06  0.343023  2.000000  1.153794  0.680148  4
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724  5

# %%
df.loc[dates[1],"A"]=10
df.iloc[2,2]=10
df
# Out:
#                     A         B          C         D  F
# 2001-01-02  -0.678828  0.821048  -0.698454 -0.089102  0
# 2001-01-03  10.000000  1.603354   1.579532 -0.998466  1
# 2001-01-04  -0.492466 -1.113067  10.000000 -1.555697  2
# 2001-01-05  -2.001224  0.887376   0.278983  1.001370  3
# 2001-01-06  -1.071654  0.081201  -0.766555 -1.199528  4
# 2001-01-07   0.164797 -0.955284   0.003420  0.198967  5

# %%
df.loc[:,"D"]=np.array([4]*len(df))
df
# Out:
#                    A         B         C  D
# 2001-01-02  1.181517 -0.317232  1.045810  4
# 2001-01-03  0.749040  0.949161  1.861586  4
# 2001-01-04  0.756808  0.726560  0.054101  4
# 2001-01-05  0.739408  0.090557  0.696008  4
# 2001-01-06 -1.378518 -0.804696  0.901295  4
# 2001-01-07 -0.299590 -0.866492  0.784695  4

# %%
df[df>0]=-df
df
# Out:
#                    A         B         C         D  F
# 2025-03-02  1.184007  0.642202  0.854320  1.009150  0
# 2025-03-03  0.424331  0.374306  0.088135  0.181276  1
# 2025-03-04  2.320543  0.112225  0.450062  0.827733  2
# 2025-03-05  1.351192  1.090371  0.671756  1.130773  3
# 2025-03-06  0.343023  2.000000  1.153794  0.680148  4
# 2025-03-07  0.785115  2.005300  0.283473  0.027724  5

# %%
df[df.loc[pd.date_range("20010102",periods=3)]<0]=-df
df
# Out:
#                     A         B          C    D  F
# 2001-01-02   0.678828  0.821048   0.698454  4.0  0
# 2001-01-03  10.000000  1.603354   1.579532  4.0  1
# 2001-01-04   0.492466  1.113067  10.000000  4.0  2
# 2001-01-05  -2.001224 -0.887376  -0.278983 -4.0 -3
# 2001-01-06  -1.071654 -0.081201  -0.766555 -4.0 -4
# 2001-01-07  -0.164797 -0.955284  -0.003420 -4.0 -5

# %%
df1=df.reindex(index=dates[0:4],columns=list(df.columns).append("E"))
df1.loc[dates[0]:dates[1],"E"]=1
df1
# alternate
df11=df.iloc[:4].copy()
df11['E']=np.nan
df11.loc[dates[0]:dates[1],["D","E"]]=1
df11
# Out:
#                    A         B         C         D  F    E
# 2025-03-02  1.184007  0.642202  0.854320  1.000000  0  1.0
# 2025-03-03  0.424331  0.374306  0.088135  1.000000  1  1.0
# 2025-03-04  2.320543  0.112225  0.450062  0.827733  2  NaN
# 2025-03-05  1.351192  1.090371  0.671756  1.130773  3  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C         D  F    E
# 2025-03-02  1.184007  0.642202  0.854320  1.009150  0  1.0
# 2025-03-03  0.424331  0.374306  0.088135  0.181276  1  1.0

# %%
df1.fillna(value=5)
# Out:
#                     A         B          C    D  F    E
# 2001-01-02   0.678828  0.821048   0.698454  4.0  0  1.0
# 2001-01-03  10.000000  1.603354   1.579532  4.0  1  1.0
# 2001-01-04   0.492466  1.113067  10.000000  4.0  2  5.0
# 2001-01-05  -2.001224 -0.887376  -0.278983 -4.0 -3  5.0

# %%
df1.isna()
# Out:
#                 A      B      C      D      F      E
# 2001-01-02  False  False  False  False  False  False
# 2001-01-03  False  False  False  False  False  False
# 2001-01-04  False  False  False  False  False   True
# 2001-01-05  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -1.219318
# B   -0.067228
# C   -3.110004
# D    4.000000
# F    1.500000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2001-01-02    0.172496
# 2001-01-03   -3.433786
# 2001-01-04   -1.890295
# 2001-01-05    2.132722
# 2001-01-06    1.917437
# 2001-01-07    2.425566
# Freq: D, dtype: float64

# %%
s=pd.Series([1,2,3,np.nan,4,5],index=dates).shift(2)
print(s)
# Out:
# 2001-01-02    NaN
# 2001-01-03    NaN
# 2001-01-04    1.0
# 2001-01-05    2.0
# 2001-01-06    3.0
# 2001-01-07    NaN
# Freq: D, dtype: float64

# %%
print(df)
df.sub(s,axis=0)
# Out:
#                    A         B         C  D
# 2001-01-02  1.181517 -0.317232  1.045810  4
# 2001-01-03  0.749040  0.949161  1.861586  4
# 2001-01-04  0.756808  0.726560  0.054101  4
# 2001-01-05  0.739408  0.090557  0.696008  4
# 2001-01-06 -1.378518 -0.804696  0.901295  4
# 2001-01-07 -0.299590 -0.866492  0.784695  4
#                    A         B         C    D
# 2001-01-02       NaN       NaN       NaN  NaN
# 2001-01-03       NaN       NaN       NaN  NaN
# 2001-01-04 -0.243192 -0.273440 -0.945899  3.0
# 2001-01-05 -1.260592 -1.909443 -1.303992  2.0
# 2001-01-06 -4.378518 -3.804696 -2.098705  1.0
# 2001-01-07       NaN       NaN       NaN  NaN

# %%
print(df)
df.agg(lambda x: np.mean(x) * 5.3)
# Out:
#                    A         B         C         D
# 2001-01-02 -0.126316 -2.356342  0.152712 -0.023029
# 2001-01-03 -0.603252  0.064910  0.555889  1.960449
# 2001-01-04 -0.697640 -0.596681 -0.534425  0.724692
# 2001-01-05 -0.311370 -0.213647 -2.078210  2.000391
# 2001-01-06  0.885305  0.334452  0.588951 -0.157670
# 2001-01-07 -0.531327  0.072648 -1.104112 -1.248158
# A   -1.223065
# B   -2.380282
# C   -2.136956
# D    2.876730
# dtype: float64

# %%
df.transform(lambda x:x*101)
# df*101
# Out:
#                     A           B           C           D
# 2001-01-02 -12.757950 -237.990500   15.423888   -2.325945
# 2001-01-03 -60.928470    6.555862   56.144818  198.005319
# 2001-01-04 -70.461627  -60.264813  -53.976934   73.193876
# 2001-01-05 -31.448387  -21.578312 -209.899200  202.039534
# 2001-01-06  89.415762   33.779683   59.484022  -15.924620
# 2001-01-07 -53.664064    7.337480 -111.515288 -126.063952

# %%
df12=pd.DataFrame(np.random.randint(0,9,(3,4)))
df12
# Out:
#    0  1  2  3
# 0  7  3  5  2
# 1  3  5  4  7
# 2  0  2  0  2

# %%
s=pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    3
# 1    5
# 2    6
# 3    0
# 4    6
# 5    5
# 6    6
# 7    0
# 8    0
# 9    0
# dtype: int32

# %%
s.value_counts(ascending=True)
# Out:
# 3    1
# 5    2
# 6    3
# 0    4
# Name: count, dtype: int64

# %%
s=pd.Series(["A","B","C",np.nan,"AA","AB"])
s.str.lower()
# Out:
# 0      a
# 1      b
# 2      c
# 3    NaN
# 4     aa
# 5     ab
# dtype: object

# %%
df=pd.DataFrame(np.random.randn(10,4))
pieces = [df[:3],df[4:7],df[8:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.094539  0.205953  0.526009 -0.811813
#  1  0.368820 -0.203449  0.323029  0.857775
#  2  0.777569 -0.515608  0.813140  1.716246,
#            0         1         2         3
#  4 -0.110354  1.261192 -1.131791 -1.284974
#  5  0.138039 -1.011833 -1.287408  0.532485
#  6 -0.759077  0.506695 -1.617788 -2.932247,
#            0         1         2         3
#  8  0.183872  0.129793  0.413312 -0.962801
#  9 -1.924039  0.873028 -0.141354  1.829965]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.094539  0.205953  0.526009 -0.811813
# 1  0.368820 -0.203449  0.323029  0.857775
# 2  0.777569 -0.515608  0.813140  1.716246
# 4 -0.110354  1.261192 -1.131791 -1.284974
# 5  0.138039 -1.011833 -1.287408  0.532485
# 6 -0.759077  0.506695 -1.617788 -2.932247
# 8  0.183872  0.129793  0.413312 -0.962801
# 9 -1.924039  0.873028 -0.141354  1.829965

# %%
left = pd.DataFrame({"key":["poo","poo"],"lval":[1,2]})
right = pd.DataFrame({"key":["poo","poo"],"rval":[3,4]})
pd.merge(left,right,on="key")
# Out:
#    key  lval  rval
# 0  poo     1     3
# 1  poo     1     4
# 2  poo     2     3
# 3  poo     2     4

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randint(0,8),
    },
    )
df
# Out:
#      A      B         C  D
# 0  foo    one -0.048665  5
# 1  bar    one -0.534972  5
# 2  foo    two -1.050997  5
# 3  bar  three -0.327205  5
# 4  foo    two  0.545131  5
# 5  bar    two  0.582152  5
# 6  foo    one -0.984889  5
# 7  foo  three  0.234659  5

# %%
print(df.groupby("A")[["C","D"]].sum())
# Out:
#             C   D
# A
# bar -0.280025  15
# foo -1.304760  25

# %%
df.groupby(["A","B"]).max()
# Out:
#                   C  D
# A   B
# bar one   -0.523587  6
#     three  0.473881  6
#     two   -0.568890  6
# foo one    0.383282  6
#     three -0.177728  6
#     two   -1.108970  6

# %%
arrays = [
    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
    ["one", "two", "one", "two", "one", "two", "one", "two"]]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df=pd.DataFrame(np.random.randn(8,2), index=index, columns=["A","B"])
df2=df[:5]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.792428 -0.528434
#       two    -1.539882  0.049743
# baz   one     0.784401 -0.036093
#       two    -0.226418 -0.656108
# foo   one     0.865103  0.126339

# %%
s=pd.Series(np.random.randn(8),index=index)
s
# Out:
# first  second
# bar    one      -0.709466
#        two       0.177237
# baz    one      -0.671788
#        two       0.148800
# foo    one      -0.084821
#        two      -0.489731
# qux    one      -1.991606
#        two      -1.701382
# dtype: float64

# %%
stacked=df2.stack(future_stack=True)
stacked
# Out:
# first  second
# bar    one     A   -0.792428
#                B   -0.528434
#        two     A   -1.539882
#                B    0.049743
# baz    one     A    0.784401
#                B   -0.036093
#        two     A   -0.226418
#                B   -0.656108
# foo    one     A    0.865103
#                B    0.126339
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.792428 -0.528434
#       two    -1.539882  0.049743
# baz   one     0.784401 -0.036093
#       two    -0.226418 -0.656108
# foo   one     0.865103  0.126339

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.792428 -1.539882
#       B -0.528434  0.049743
# baz   A  0.784401 -0.226418
#       B -0.036093 -0.656108
# foo   A  0.865103       NaN
#       B  0.126339       NaN

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
        "F": np.random.randint(0,10),
    }
)
df
# Out:
#         A  B    C         D         E  F
# 0     one  A  foo  0.898204  0.315650  6
# 1     one  B  foo  0.692939 -2.002714  6
# 2     two  C  foo  0.343731  0.734554  6
# 3   three  A  bar  0.323923  2.801709  6
# 4     one  B  bar  1.278992 -0.828457  6
# 5     one  C  bar -0.646873 -1.140004  6
# 6     two  A  foo -0.057004 -0.492756  6
# 7   three  B  foo  0.065952 -1.668611  6
# 8     one  C  foo  0.243016  0.422143  6
# 9     one  A  bar  0.005382  1.871104  6
# 10    two  B  bar -0.767995 -0.012292  6
# 11  three  C  bar  0.857880  0.364309  6

# %%
pd.pivot_table(df, values=["D"],index=["A","B"],columns=["C"])
# Out:
#                 D
# C             bar       foo
# A     B
# one   A  0.005382  0.898204
#       B  1.278992  0.692939
#       C -0.646873  0.243016
# three A  0.323923       NaN
#       B       NaN  0.065952
#       C  0.857880       NaN
# two   A       NaN -0.057004
#       B -0.767995       NaN
#       C       NaN  0.343731

# %%
rng=pd.date_range("20010102",periods=100,freq="s")
ts=pd.Series(np.random.randint(0,500,len(rng)),index=rng)
ts.resample("1Min").sum()
# Out:
# 2001-01-02 00:00:00    16445
# 2001-01-02 00:01:00     8581
# Freq: min, dtype: int32

# %%
rng =pd.date_range("01/02/2001 00:00",periods=5,freq="D")
ts=pd.Series(np.random.randn(len(rng)),rng)
ts
# Out:
# 2001-01-02    0.160304
# 2001-01-03   -0.410484
# 2001-01-04   -0.096419
# 2001-01-05   -0.259545
# 2001-01-06    0.160198
# Freq: D, dtype: float64

# %%
tz=ts.tz_localize("UTC")
tz
# Out:
# 2001-01-02 00:00:00+00:00    0.160304
# 2001-01-03 00:00:00+00:00   -0.410484
# 2001-01-04 00:00:00+00:00   -0.096419
# 2001-01-05 00:00:00+00:00   -0.259545
# 2001-01-06 00:00:00+00:00    0.160198
# Freq: D, dtype: float64

# %%
tz.tz_convert("US/Eastern")
# Out:
# 2001-01-01 19:00:00-05:00    0.160304
# 2001-01-02 19:00:00-05:00   -0.410484
# 2001-01-03 19:00:00-05:00   -0.096419
# 2001-01-04 19:00:00-05:00   -0.259545
# 2001-01-05 19:00:00-05:00    0.160198
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2001-01-02', '2001-01-03', '2001-01-04', '2001-01-05',
#                '2001-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng+pd.offsets.BusinessDay(5) #sunday & sat skip
# Out:
# DatetimeIndex(['2001-01-09', '2001-01-10', '2001-01-11', '2001-01-12',
#                '2001-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6],"raw_grade":["a","b","b","a","a","e"]})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"]=df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good","good","very bad"]
df["grade"]=df["grade"].cat.rename_categories(new_categories)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
df["grade"]=df["grade"].cat.set_categories(["very bad","bad","medium","good","very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade",observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts=pd.Series(np.random.randn(1000),pd.date_range("02/01/2001",periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=["A","B","C","D"])
df=df.cumsum()
plt.figure()
df.plot()
plt.legend(loc="best")

# %%
df=pd.DataFrame(np.random.randint(0,5,(10,5)))
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  3  1  4  0
# 1           1  1  2  0  1  4
# 2           2  0  2  3  2  3
# 3           3  3  2  1  1  3
# 4           4  3  3  2  4  4
# 5           5  4  1  2  0  2
# 6           6  3  1  3  0  1
# 7           7  1  0  4  1  2
# 8           8  4  2  1  2  2
# 9           9  1  1  1  1  4

# %%
df.to_parquet("foo.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[71], line 2
#       1 import pyarrow, fastparquet
# ----> 2 df.to_parquet("foo.parquet")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
# ...

# %%
df.to_excel('foo.xlsx',sheet_name="sheet1")

# %%
pd.read_excel("foo.xlsx","sheet1",index_col=None,na_values=["NA"])
# Out:
#    Unnamed: 0  1  2  3  4
# 0
# 3           0  3  1  3  4
# 1           1  2  0  0  0
# 3           2  4  2  3  4
# 0           3  2  0  4  0
# 1           4  0  2  3  2
# 3           5  3  4  0  0
# 3           6  1  0  3  2
# 0           7  0  3  1  1
# 3           8  1  3  3  2
# 0           9  2  0  0  3
