# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s.describe()
# Out:
# count    5.000000
# mean     4.600000
# std      2.701851
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      6.000000
# max      8.000000
# dtype: float64

# %%
dates= pd.date_range("20250302", periods=6)
print(dates)
df= pd.DataFrame(np.random.randn(6,4), index=dates)
df
# Out:
# DatetimeIndex(['2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05',
#                '2025-03-06', '2025-03-07'],
#               dtype='datetime64[ns]', freq='D')
#                    0         1         2         3
# 2025-03-02  2.311945 -0.301218  0.627879 -1.263205
# 2025-03-03  0.175155  2.127224  0.533088 -0.991845
# 2025-03-04 -0.213381 -1.415624  0.771871  0.467128
# 2025-03-05 -1.834732  0.338477 -0.577329  0.116673
# 2025-03-06 -0.418898 -0.572609  0.380394 -2.738594
# 2025-03-07  1.421382 -0.172467  0.275631 -1.942984

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(list(range(10,14)), index=list(range(4)), dtype="float32"),
        "D": np.array([3,2] * 2, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B     C  D      E    F
# 0  1.0 2013-01-02  10.0  3   test  foo
# 1  1.0 2013-01-02  11.0  2  train  foo
# 2  1.0 2013-01-02  12.0  3   test  foo
# 3  1.0 2013-01-02  13.0  2  train  foo

# %%
print(df.head(3))
print(df.tail(2))
# Out:
#                    0         1         2         3
# 2025-03-02 -1.671601  0.230678 -0.043917 -0.267089
# 2025-03-03  0.332214  1.170346  0.853293  0.356378
# 2025-03-04 -1.581114  0.663035 -1.881219  1.284768
#                    0         1         2         3
# 2025-03-06 -0.406110 -0.279302 -0.616976  0.752637
# 2025-03-07 -1.777144 -0.379537  0.795675  0.356312

# %%
print(df.index)
print(df.columns)
# Out:
# DatetimeIndex(['2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05',
#                '2025-03-06', '2025-03-07'],
#               dtype='datetime64[ns]', freq='D')
# RangeIndex(start=0, stop=4, step=1)

# %%
df.to_numpy()
# Out:
# array([[-1.18400717, -0.64220158, -0.85432019, -1.00915009],
#        [-0.42433146, -0.37430599, -0.08813533, -0.18127638],
#        [-2.32054308, -0.11222519, -0.45006179, -0.82773345],
#        [ 1.35119237,  1.09037063, -0.67175588, -1.13077306],
#        [ 0.34302291, -1.54956341,  1.15379406,  0.68014772],
#        [ 0.78511529, -2.00530047, -0.28347309, -0.02772362]])

# %%
print(pd.DataFrame(df.to_numpy()))
print(pd.DataFrame(df.to_numpy().reshape(4, 6)))
# Out:
#           0         1         2         3
# 0 -1.184007 -0.642202 -0.854320 -1.009150
# 1 -0.424331 -0.374306 -0.088135 -0.181276
# 2 -2.320543 -0.112225 -0.450062 -0.827733
# 3  1.351192  1.090371 -0.671756 -1.130773
# 4  0.343023 -1.549563  1.153794  0.680148
# 5  0.785115 -2.005300 -0.283473 -0.027724
#           0         1         2         3         4         5
# 0 -1.184007 -0.642202 -0.854320 -1.009150 -0.424331 -0.374306
# 1 -0.088135 -0.181276 -2.320543 -0.112225 -0.450062 -0.827733
# 2  1.351192  1.090371 -0.671756 -1.130773  0.343023 -1.549563
# 3  1.153794  0.680148  0.785115 -2.005300 -0.283473 -0.027724

# %%
print(df.describe())
print(df.sum())
# Out:
#               0         1         2         3
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.767072  0.063772 -0.094511  0.427088
# std    1.043899  0.788147  1.033007  0.539313
# min   -1.777144 -1.022586 -1.881219 -0.267089
# 25%   -1.648979 -0.354479 -0.473711  0.148719
# 50%   -0.993612 -0.024312  0.141080  0.356345
# 75%    0.147633  0.554945  0.678275  0.653572
# max    0.501321  1.170346  0.853293  1.284768
# 0   -4.602433
# 1    0.382632
# 2   -0.567067
# 3    2.562528
# dtype: float64

# %%
df.T
# Out:
#    2025-03-02  2025-03-03  2025-03-04  2025-03-05  2025-03-06  2025-03-07
# 0   -1.184007   -0.424331   -2.320543    1.351192    0.343023    0.785115
# 1   -0.642202   -0.374306   -0.112225    1.090371   -1.549563   -2.005300
# 2   -0.854320   -0.088135   -0.450062   -0.671756    1.153794   -0.283473
# 3   -1.009150   -0.181276   -0.827733   -1.130773    0.680148   -0.027724

# %%
print(df.sort_index(ascending=False))
print(df.sort_index(axis=1, ascending=False))
# Out:
#                    0         1         2         3
# 2025-03-07 -1.777144 -0.379537  0.795675  0.356312
# 2025-03-06 -0.406110 -0.279302 -0.616976  0.752637
# 2025-03-05  0.501321 -1.022586  0.326078  0.079521
# 2025-03-04 -1.581114  0.663035 -1.881219  1.284768
# 2025-03-03  0.332214  1.170346  0.853293  0.356378
# 2025-03-02 -1.671601  0.230678 -0.043917 -0.267089
#                    3         2         1         0
# 2025-03-02 -0.267089 -0.043917  0.230678 -1.671601
# 2025-03-03  0.356378  0.853293  1.170346  0.332214
# 2025-03-04  1.284768 -1.881219  0.663035 -1.581114
# 2025-03-05  0.079521  0.326078 -1.022586  0.501321
# 2025-03-06  0.752637 -0.616976 -0.279302 -0.406110
# 2025-03-07  0.356312  0.795675 -0.379537 -1.777144

# %%
print(df2.sort_values(by="B"))
print(df.sort_values(by='20250307', axis=1))
# Out:
#      A          B     C  D      E    F
# 0  1.0 2013-01-02  10.0  3   test  foo
# 1  1.0 2013-01-02  11.0  2  train  foo
# 2  1.0 2013-01-02  12.0  3   test  foo
# 3  1.0 2013-01-02  13.0  2  train  foo
#                    0         1         3         2
# 2025-03-02 -1.671601  0.230678 -0.267089 -0.043917
# 2025-03-03  0.332214  1.170346  0.356378  0.853293
# 2025-03-04 -1.581114  0.663035  1.284768 -1.881219
# 2025-03-05  0.501321 -1.022586  0.079521  0.326078
# 2025-03-06 -0.406110 -0.279302  0.752637 -0.616976
# 2025-03-07 -1.777144 -0.379537  0.356312  0.795675

# %%
df1= df.T
df1.sort_values(by="20250307",ascending=False)
# Out:
#    2025-03-02  2025-03-03  2025-03-04  2025-03-05  2025-03-06  2025-03-07
# 0   -1.184007   -0.424331   -2.320543    1.351192    0.343023    0.785115
# 3   -1.009150   -0.181276   -0.827733   -1.130773    0.680148   -0.027724
# 2   -0.854320   -0.088135   -0.450062   -0.671756    1.153794   -0.283473
# 1   -0.642202   -0.374306   -0.112225    1.090371   -1.549563   -2.005300

# %%
df[1]
# Out:
# 2025-03-02   -0.642202
# 2025-03-03   -0.374306
# 2025-03-04   -0.112225
# 2025-03-05    1.090371
# 2025-03-06   -1.549563
# 2025-03-07   -2.005300
# Freq: D, Name: 1, dtype: float64

# %%
df[0:4:2]
# Out:
#                    0         1         2         3
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733

# %%
print(df["20250302":"20250306":2])
# Out:
#                    A         B         C         D  F
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150  0
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733  2
# 2025-03-06  0.343023  2.000000  1.153794  0.680148  4

# %%
print(df.loc[dates[0]])
df.columns
df[0]
# Out:
# 0    2.311945
# 1   -0.301218
# 2    0.627879
# 3   -1.263205
# Name: 2025-03-02 00:00:00, dtype: float64
# 2025-03-02    2.311945
# 2025-03-03    0.175155
# 2025-03-04   -0.213381
# 2025-03-05   -1.834732
# 2025-03-06   -0.418898
# 2025-03-07    1.421382
# Freq: D, Name: 0, dtype: float64

# %%
df.columns= list("ABCD")
df.loc[:,list("AB")]
# Out:
#                    A         B
# 2025-03-02 -1.184007 -0.642202
# 2025-03-03 -0.424331 -0.374306
# 2025-03-04 -2.320543 -0.112225
# 2025-03-05  1.351192  1.090371
# 2025-03-06  0.343023 -1.549563
# 2025-03-07  0.785115 -2.005300

# %%
print(df.loc[dates[0],"A"])
# Out:
# -1.1840071721405434

# %%
df.iloc[3]
# Out:
# A   -0.311370
# B   -0.213647
# C   -2.078210
# D    2.000391
# Name: 2001-01-05 00:00:00, dtype: float64

# %%
print(df.iloc[0:5,0:2])
print(df.iloc[0:5:2,0:4:2])
# Out:
#                    A         B
# 2025-03-02 -1.184007 -0.642202
# 2025-03-03 -0.424331 -0.374306
# 2025-03-04 -2.320543 -0.112225
# 2025-03-05  1.351192  1.090371
# 2025-03-06  0.343023 -1.549563
#                    A         C
# 2025-03-02 -1.184007 -0.854320
# 2025-03-04 -2.320543 -0.450062
# 2025-03-06  0.343023  1.153794

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2001-01-03 -0.603252  0.555889
# 2001-01-04 -0.697640 -0.534425
# 2001-01-06  0.885305  0.588951

# %%
df.iloc[0,0]
# Out:
# np.float64(0.8099620811348688)

# %%
print(df["A"]>0)
df[df["A"]>0]
# Out:
# 2025-03-02    False
# 2025-03-03    False
# 2025-03-04    False
# 2025-03-05     True
# 2025-03-06     True
# 2025-03-07     True
# Freq: D, Name: A, dtype: bool
#                    A         B         C         D
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773
# 2025-03-06  0.343023 -1.549563  1.153794  0.680148
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724

# %%
df.iloc[4,1]= 2.00
print(df[df>0])
df[df>0].dropna()
# Out:
#                    0         1         2         3
# 2025-03-02       NaN  0.230678       NaN       NaN
# 2025-03-03  0.332214  1.170346  0.853293  0.356378
# 2025-03-04       NaN  0.663035       NaN  1.284768
# 2025-03-05  0.501321       NaN  0.326078  0.079521
# 2025-03-06       NaN  2.000000       NaN  0.752637
# 2025-03-07       NaN       NaN  0.795675  0.356312
#                    0         1         2         3
# 2025-03-03  0.332214  1.170346  0.853293  0.356378

# %%
print(df.count())
print(df.loc['20250306'])
print(df.loc[pd.Timestamp("20250306")].sum())
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# dtype: int64
# 0   -0.326225
# 1    1.188864
# 2    1.291798
# 3    1.106562
# Name: 2025-03-06 00:00:00, dtype: float64
# 3.261000083580482

# %%
df2=df.copy()
df2['E']=["one","one","two","three","four","five"]
print(df)
df2
# Out:
#                    A         B         C         D      E
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150    one
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276    one
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733    two
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773  three
# 2025-03-06  0.343023  2.000000  1.153794  0.680148   four
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724   five

# %%
print(df2[df2["E"].isin(["one"])])
print(df2[~df2["E"].isin(['one'])])
# Out:
#                    A         B         C         D    E
# 2025-03-02 -1.184007 -0.642202 -0.854320 -1.009150  one
# 2025-03-03 -0.424331 -0.374306 -0.088135 -0.181276  one
#                    A         B         C         D      E
# 2025-03-04 -2.320543 -0.112225 -0.450062 -0.827733    two
# 2025-03-05  1.351192  1.090371 -0.671756 -1.130773  three
# 2025-03-06  0.343023  2.000000  1.153794  0.680148   four
# 2025-03-07  0.785115 -2.005300 -0.283473 -0.027724   five

# %%
df2[~df2["E"].isin(["one"])]
df2[df2["E"].isin(["one"])==False]
# Out:
#                    A         B         C         D      E
# 2001-01-04 -0.492466 -1.113067 -1.032611 -1.555697    two
# 2001-01-05 -2.001224  0.887376  0.278983  1.001370  three
# 2001-01-06 -1.071654  0.081201 -0.766555 -1.199528   four
# 2001-01-07  0.164797 -0.955284  0.003420  0.198967   five

# %%
s1 = pd.Series(list(range(6)),index=pd.date_range("20250303",periods=6))
df["F"]=s1
df
# Out:
#           0         1         2         3   F
# 0  0.145807 -0.357860 -0.173144  1.033271 NaN
# 1  0.327007  0.355653 -1.339067 -2.149662 NaN
# 2  0.678444 -2.026321 -0.896813 -0.523650 NaN
# 3  1.371217  0.081988 -0.555241 -0.850310 NaN
# 4  0.407912 -1.076311 -0.024507  0.339479 NaN
# 5  1.629653 -0.229525 -1.768494 -0.678256 NaN
# 6  0.556129 -0.924852 -0.218753 -1.474027 NaN
# 7 -0.457207  0.009276 -0.688482  0.138426 NaN
# 8  0.891908  0.664556 -1.282911 -0.669928 NaN
# 9 -0.719037 -1.194628  0.184557  0.311068 NaN

# %%
df.loc[dates[1],"A"]=10
df.iloc[2,2]=10
df
# Out:
#                     A         B          C         D  F
# 2001-01-02  -0.678828  0.821048  -0.698454 -0.089102  0
# 2001-01-03  10.000000  1.603354   1.579532 -0.998466  1
# 2001-01-04  -0.492466 -1.113067  10.000000 -1.555697  2
# 2001-01-05  -2.001224  0.887376   0.278983  1.001370  3
# 2001-01-06  -1.071654  0.081201  -0.766555 -1.199528  4
# 2001-01-07   0.164797 -0.955284   0.003420  0.198967  5

# %%
df.loc[:,"D"]=np.array([4]*len(df))
df
# Out:
#                    0         1         2         3    F  D
# 2025-03-02  1.369838 -0.563656  1.544931 -1.664513  NaN  4
# 2025-03-03 -1.901414  0.655266  0.908725  1.891708  0.0  4
# 2025-03-04 -1.170694  0.271441  0.540987 -0.358884  1.0  4
# 2025-03-05 -2.314936  0.687510  0.366790 -0.133658  2.0  4
# 2025-03-06 -0.326225  1.188864  1.291798  1.106562  3.0  4
# 2025-03-07 -0.611941  0.539687  0.247031 -1.317448  4.0  4

# %%
df[df>0]=-df
df
# Out:
#                    0         1         2         3    F  D
# 2025-03-02 -1.369838 -0.563656 -1.544931 -1.664513  NaN -4
# 2025-03-03 -1.901414 -0.655266 -0.908725 -1.891708  0.0 -4
# 2025-03-04 -1.170694 -0.271441 -0.540987 -0.358884 -1.0 -4
# 2025-03-05 -2.314936 -0.687510 -0.366790 -0.133658 -2.0 -4
# 2025-03-06 -0.326225 -1.188864 -1.291798 -1.106562 -3.0 -4
# 2025-03-07 -0.611941 -0.539687 -0.247031 -1.317448 -4.0 -4

# %%
df[df.loc[pd.date_range("20010102",periods=3)]<0]=-df
df
# Out:
#                     A         B          C    D  F
# 2001-01-02   0.678828  0.821048   0.698454  4.0  0
# 2001-01-03  10.000000  1.603354   1.579532  4.0  1
# 2001-01-04   0.492466  1.113067  10.000000  4.0  2
# 2001-01-05  -2.001224 -0.887376  -0.278983 -4.0 -3
# 2001-01-06  -1.071654 -0.081201  -0.766555 -4.0 -4
# 2001-01-07  -0.164797 -0.955284  -0.003420 -4.0 -5

# %%
df1=df.reindex(index=dates[0:4],columns=list(df.columns).append("E"))
df1.loc[dates[0]:dates[1],"E"]=1
df1
# alternate
df11=df.iloc[:4].copy()
df11['E']=np.nan
df11.loc[dates[0]:dates[1],["D","E"]]=1
df11
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6853, in Index.get_slice_bound(self, label, side)
#    6852 try:
# -> 6853     slc = self.get_loc(label)
#    6854 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#
# KeyError: Timestamp('2025-03-02 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 7
#       5 df11=df.iloc[:4].copy()
#       6 df11['E']=np.nan
# ----> 7 df11.loc[dates[0]:dates[1],["D","E"]]=1
#       8 df11
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:908, in _LocationIndexer.__setitem__(self, key, value)
#     906     maybe_callable = com.apply_if_callable(key, self.obj)
#     907     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 908 indexer = self._get_setitem_indexer(key)
#     909 self._has_valid_setitem_indexer(key)
#     911 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:775, in _LocationIndexer._get_setitem_indexer(self, key)
#     772 if isinstance(key, tuple):
#     773     with suppress(IndexingError):
#     774         # suppress "Too many indexers"
# --> 775         return self._convert_tuple(key)
#     777 if isinstance(key, range):
#     778     # GH#45479 test_loc_setitem_range_key
#     779     key = list(key)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:990, in _LocationIndexer._convert_tuple(self, key)
#     986 @final
#     987 def _convert_tuple(self, key: tuple) -> tuple:
#     988     # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     989     self._validate_key_length(key)
# --> 990     keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     991     return tuple(keyidx)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1471, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1468 labels = self.obj._get_axis(axis)
#    1470 if isinstance(key, slice):
# -> 1471     return labels._convert_slice_indexer(key, kind="loc")
#    1473 if (
#    1474     isinstance(key, tuple)
#    1475     and not isinstance(labels, MultiIndex)
#    1476     and self.ndim < 2
#    1477     and len(key) > 1
#    1478 ):
#    1479     raise IndexingError("Too many indexers")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:4288, in Index._convert_slice_indexer(self, key, kind)
#    4286     indexer = key
#    4287 else:
# -> 4288     indexer = self.slice_indexer(start, stop, step)
#    4290 return indexer
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6708, in Index.slice_indexer(self, start, end, step)
#    6664 def slice_indexer(
#    6665     self,
#    6666     start: Hashable | None = None,
#    6667     end: Hashable | None = None,
#    6668     step: int | None = None,
#    6669 ) -> slice:
#    6670     """
#    6671     Compute the slice indexer for input labels and step.
#    6672
#    (...)   6706     slice(1, 3, None)
#    6707     """
# -> 6708     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6710     # return a slice
#    6711     if not is_scalar(start_slice):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6934, in Index.slice_locs(self, start, end, step)
#    6932 start_slice = None
#    6933 if start is not None:
# -> 6934     start_slice = self.get_slice_bound(start, "left")
#    6935 if start_slice is None:
#    6936     start_slice = 0
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6856, in Index.get_slice_bound(self, label, side)
#    6854 except KeyError as err:
#    6855     try:
# -> 6856         return self._searchsorted_monotonic(label, side)
#    6857     except ValueError:
#    6858         # raise the original KeyError
#    6859         raise err
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6788, in Index._searchsorted_monotonic(self, label, side)
#    6786 def _searchsorted_monotonic(self, label, side: Literal["left", "right"] = "left"):
#    6787     if self.is_monotonic_increasing:
# -> 6788         return self.searchsorted(label, side=side)
#    6789     elif self.is_monotonic_decreasing:
#    6790         # np.searchsorted expects ascending sort order, have to reverse
#    6791         # everything for it to work (element ordering, search side and
#    6792         # resulting value).
#    6793         pos = self[::-1].searchsorted(
#    6794             label, side="right" if side == "left" else "left"
#    6795         )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\base.py:1361, in IndexOpsMixin.searchsorted(self, value, side, sorter)
#    1357 if not isinstance(values, np.ndarray):
#    1358     # Going through EA.searchsorted directly improves performance GH#38083
#    1359     return values.searchsorted(value, side=side, sorter=sorter)
# -> 1361 return algorithms.searchsorted(
#    1362     values,
#    1363     value,
#    1364     side=side,
#    1365     sorter=sorter,
#    1366 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\algorithms.py:1329, in searchsorted(arr, value, side, sorter)
#    1325     arr = ensure_wrapped_if_datetimelike(arr)
#    1327 # Argument 1 to "searchsorted" of "ndarray" has incompatible type
#    1328 # "Union[NumpyValueArrayLike, ExtensionArray]"; expected "NumpyValueArrayLike"
# -> 1329 return arr.searchsorted(value, side=side, sorter=sorter)
#
# TypeError: '<' not supported between instances of 'int' and 'Timestamp'

# %%
print(df1.dropna(how="any"))
print(df1.dropna(how="all"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 print(df1.dropna(how="any"))
#       2 print(df1.dropna(how="all"))
#
# NameError: name 'df1' is not defined

# %%
df1.fillna(value=5)
# Out:
#                     A         B          C    D  F    E
# 2001-01-02   0.678828  0.821048   0.698454  4.0  0  1.0
# 2001-01-03  10.000000  1.603354   1.579532  4.0  1  1.0
# 2001-01-04   0.492466  1.113067  10.000000  4.0  2  5.0
# 2001-01-05  -2.001224 -0.887376  -0.278983 -4.0 -3  5.0

# %%
df1.isna()
# Out:
#                 A      B      C      D      F      E
# 2001-01-02  False  False  False  False  False  False
# 2001-01-03  False  False  False  False  False  False
# 2001-01-04  False  False  False  False  False   True
# 2001-01-05  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -1.219318
# B   -0.067228
# C   -3.110004
# D    4.000000
# F    1.500000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2001-01-02    0.172496
# 2001-01-03   -3.433786
# 2001-01-04   -1.890295
# 2001-01-05    2.132722
# 2001-01-06    1.917437
# 2001-01-07    2.425566
# Freq: D, dtype: float64

# %%
s=pd.Series([1,2,3,np.nan,4,5],index=dates).shift(2)
print(s)
# Out:
# 2025-03-02    NaN
# 2025-03-03    NaN
# 2025-03-04    1.0
# 2025-03-05    2.0
# 2025-03-06    3.0
# 2025-03-07    NaN
# Freq: D, dtype: float64

# %%
print(df)
df.sub(s,axis=0)
# Out:
#                    0         1         2         3    F  D
# 2025-03-02 -1.369838 -0.563656 -1.544931 -1.664513  NaN -4
# 2025-03-03 -1.901414 -0.655266 -0.908725 -1.891708  0.0 -4
# 2025-03-04 -1.170694 -0.271441 -0.540987 -0.358884 -1.0 -4
# 2025-03-05 -2.314936 -0.687510 -0.366790 -0.133658 -2.0 -4
# 2025-03-06 -0.326225 -1.188864 -1.291798 -1.106562 -3.0 -4
# 2025-03-07 -0.611941 -0.539687 -0.247031 -1.317448 -4.0 -4
#                    0         1         2         3    F    D
# 2025-03-02       NaN       NaN       NaN       NaN  NaN  NaN
# 2025-03-03       NaN       NaN       NaN       NaN  NaN  NaN
# 2025-03-04 -2.170694 -1.271441 -1.540987 -1.358884 -2.0 -5.0
# 2025-03-05 -4.314936 -2.687510 -2.366790 -2.133658 -4.0 -6.0
# 2025-03-06 -3.326225 -4.188864 -4.291798 -4.106562 -6.0 -7.0
# 2025-03-07       NaN       NaN       NaN       NaN  NaN  NaN

# %%
print(df)
print(df.agg(lambda x: np.mean(x) * 5.3))
print(df.agg(lambda x: np.mean(x)* 5.3, axis=1))
# Out:
#           0         1         2         3
# 0  0.145807 -0.357860 -0.173144  1.033271
# 1  0.327007  0.355653 -1.339067 -2.149662
# 2  0.678444 -2.026321 -0.896813 -0.523650
# 3  1.371217  0.081988 -0.555241 -0.850310
# 4  0.407912 -1.076311 -0.024507  0.339479
# 5  1.629653 -0.229525 -1.768494 -0.678256
# 6  0.556129 -0.924852 -0.218753 -1.474027
# 7 -0.457207  0.009276 -0.688482  0.138426
# 8  0.891908  0.664556 -1.282911 -0.669928
# 9 -0.719037 -1.194628  0.184557  0.311068
# 0    2.560871
# 1   -2.489952
# 2   -3.584313
# 3   -2.397503
# dtype: float64
# 0    0.858698
# 1   -3.718042
# 2   -3.668050
# 3    0.063142
# 4   -0.468292
# 5   -1.386775
# 6   -2.731491
# 7   -1.322332
# 8   -0.525196
# 9   -1.878904
# dtype: float64

# %%
df.transform(lambda x:x*101)
# df*101
# Out:
#                     A           B           C           D
# 2001-01-02 -12.757950 -237.990500   15.423888   -2.325945
# 2001-01-03 -60.928470    6.555862   56.144818  198.005319
# 2001-01-04 -70.461627  -60.264813  -53.976934   73.193876
# 2001-01-05 -31.448387  -21.578312 -209.899200  202.039534
# 2001-01-06  89.415762   33.779683   59.484022  -15.924620
# 2001-01-07 -53.664064    7.337480 -111.515288 -126.063952

# %%
df12=pd.DataFrame(np.random.randint(0,9,(3,4)))
df12
# Out:
#    0  1  2  3
# 0  7  3  5  2
# 1  3  5  4  7
# 2  0  2  0  2

# %%
s=pd.Series(np.random.randint(0,7,size=10))
s=pd.Series(np.random.randint(0,7,10))
s
# Out:
# 0    2
# 1    0
# 2    4
# 3    5
# 4    1
# 5    1
# 6    0
# 7    6
# 8    2
# 9    5
# dtype: int32

# %%
print(s.value_counts(ascending=True))
print(s.groupby(s).count().sort_values())
print(s.count())
# Out:
# 3    1
# 5    1
# 6    2
# 4    2
# 2    4
# Name: count, dtype: int64
# 3    1
# 5    1
# 4    2
# 6    2
# 2    4
# dtype: int64
# 10

# %%
s=pd.Series(["A","B","C",np.nan,"AA","AB"])
s.str.lower()
# Out:
# 0    2.0
# 1    3.0
# 2    2.0
# 3    3.0
# 4    2.0
# 5    3.0
# dtype: float32
# 0      a
# 1      b
# 2      c
# 3    NaN
# 4     aa
# 5     ab
# dtype: object

# %%
df=pd.DataFrame(np.random.randn(10,4))
pieces = [df[:3],df[4:7],df[8:]]
piece1= df[:5]
piece2= df[5:]
pieces
# Out:
# [          0         1         2         3
#  0  0.145807 -0.357860 -0.173144  1.033271
#  1  0.327007  0.355653 -1.339067 -2.149662
#  2  0.678444 -2.026321 -0.896813 -0.523650,
#            0         1         2         3
#  4  0.407912 -1.076311 -0.024507  0.339479
#  5  1.629653 -0.229525 -1.768494 -0.678256
#  6  0.556129 -0.924852 -0.218753 -1.474027,
#            0         1         2         3
#  8  0.891908  0.664556 -1.282911 -0.669928
#  9 -0.719037 -1.194628  0.184557  0.311068]

# %%
print(pd.concat([piece1, piece2]))
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.145807 -0.357860 -0.173144  1.033271
# 1  0.327007  0.355653 -1.339067 -2.149662
# 2  0.678444 -2.026321 -0.896813 -0.523650
# 3  1.371217  0.081988 -0.555241 -0.850310
# 4  0.407912 -1.076311 -0.024507  0.339479
# 5  1.629653 -0.229525 -1.768494 -0.678256
# 6  0.556129 -0.924852 -0.218753 -1.474027
# 7 -0.457207  0.009276 -0.688482  0.138426
# 8  0.891908  0.664556 -1.282911 -0.669928
# 9 -0.719037 -1.194628  0.184557  0.311068
#           0         1         2         3
# 0  0.145807 -0.357860 -0.173144  1.033271
# 1  0.327007  0.355653 -1.339067 -2.149662
# 2  0.678444 -2.026321 -0.896813 -0.523650
# 4  0.407912 -1.076311 -0.024507  0.339479
# 5  1.629653 -0.229525 -1.768494 -0.678256
# 6  0.556129 -0.924852 -0.218753 -1.474027
# 8  0.891908  0.664556 -1.282911 -0.669928
# 9 -0.719037 -1.194628  0.184557  0.311068

# %%
left = pd.DataFrame({"key":["poo","poo"],"lval":[1,2]})
right = pd.DataFrame({"key":["poo","poo"],"rval":[3,4]})
# pd.merge(left,right,left_on="key", right_on='key', how='inner')
pd.merge(left,right,on="key")
# Out:
#    key  lval  rval
# 0  poo     1     3
# 1  poo     1     4
# 2  poo     2     3
# 3  poo     2     4

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randint(0,8),
    },
    )
df
# Out:
#      A      B         C  D
# 0  foo    one -2.543101  6
# 1  bar    one  0.999364  6
# 2  foo    two -0.918204  6
# 3  bar  three -0.426650  6
# 4  foo    two  0.319582  6
# 5  bar    two  1.481308  6
# 6  foo    one -1.074688  6
# 7  foo  three  0.715995  6

# %%
print(df.groupby("A")['C'])
# print(df.groupby("A")[1:].sum())
# Slicing can't be applied here
print(df.groupby("A")[["C","D"]].sum())
print(df.groupby("A").sum())
df.loc[:,['A']]
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x000002227CFFADD0>
#             C   D
# A
# bar  2.054022  18
# foo -3.500415  30
#                      B         C   D
# A
# bar        onethreetwo  2.054022  18
# foo  onetwotwoonethree -3.500415  30
#      A
# 0  foo
# 1  bar
# 2  foo
# 3  bar
# 4  foo
# 5  bar
# 6  foo
# 7  foo

# %%
df.groupby(["A","B"]).max()
# Out:
#                   C  D
# A   B
# bar one    0.074979  2
#     three -1.094487  2
#     two    0.861978  2
# foo one    1.442641  2
#     three  2.547089  2
#     two    0.900491  2

# %%
arrays = [
    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
    ["one", "two", "one", "two", "one", "two", "one", "two"]]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df=pd.DataFrame(np.random.randn(8,2), index=index, columns=["A","B"])
df2=df[:5]
df2
# Out:
#                      A         B
# first second
# bar   one    -1.756354 -0.384961
#       two    -0.915301 -0.758437
# baz   one     0.256413  1.487742
#       two     0.663407 -0.242322
# foo   one     0.896567  0.872676

# %%
s=pd.Series(np.random.randn(8),index=index)
s
# Out:
# first  second
# bar    one      -1.193154
#        two      -0.916199
# baz    one      -0.999576
#        two      -1.687718
# foo    one      -0.531121
#        two       0.923445
# qux    one       0.532051
#        two       0.374341
# dtype: float64

# %%
stacked=df2.stack(future_stack=True)
stacked
# Out:
# first  second
# bar    one     A   -1.756354
#                B   -0.384961
#        two     A   -0.915301
#                B   -0.758437
# baz    one     A    0.256413
#                B    1.487742
#        two     A    0.663407
#                B   -0.242322
# foo    one     A    0.896567
#                B    0.872676
# dtype: float64

# %%
print(stacked)
stacked.unstack()
# Out:
# first  second
# bar    one     A   -1.756354
#                B   -0.384961
#        two     A   -0.915301
#                B   -0.758437
# baz    one     A    0.256413
#                B    1.487742
#        two     A    0.663407
#                B   -0.242322
# foo    one     A    0.896567
#                B    0.872676
# dtype: float64
#                      A         B
# first second
# bar   one    -1.756354 -0.384961
#       two    -0.915301 -0.758437
# baz   one     0.256413  1.487742
#       two     0.663407 -0.242322
# foo   one     0.896567  0.872676

# %%
print(df2)
print(stacked)
stacked.unstack(1)
# Out:
#                      A         B
# first second
# bar   one    -1.756354 -0.384961
#       two    -0.915301 -0.758437
# baz   one     0.256413  1.487742
#       two     0.663407 -0.242322
# foo   one     0.896567  0.872676
# first  second
# bar    one     A   -1.756354
#                B   -0.384961
#        two     A   -0.915301
#                B   -0.758437
# baz    one     A    0.256413
#                B    1.487742
#        two     A    0.663407
#                B   -0.242322
# foo    one     A    0.896567
#                B    0.872676
# dtype: float64
# second        one       two
# first
# bar   A -1.756354 -0.915301
#       B -0.384961 -0.758437
# baz   A  0.256413  0.663407
#       B  1.487742 -0.242322
# foo   A  0.896567       NaN
#       B  0.872676       NaN

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
        "F": np.random.randint(0,10),
    }
)
df
# Out:
#         A  B    C         D         E  F
# 0     one  A  foo  1.285468  0.960809  0
# 1     one  B  foo  0.409710 -0.016010  0
# 2     two  C  foo  0.270670  1.133425  0
# 3   three  A  bar -0.260025 -0.785305  0
# 4     one  B  bar -0.584834 -1.337881  0
# 5     one  C  bar  0.456271 -0.494864  0
# 6     two  A  foo  0.061973  1.786990  0
# 7   three  B  foo -0.952433  0.063915  0
# 8     one  C  foo  0.880501 -2.356909  0
# 9     one  A  bar  0.369842  1.324265  0
# 10    two  B  bar -2.552582 -0.754841  0
# 11  three  C  bar -0.162200  0.374265  0

# %%
pd.pivot_table(df, values=["D"],index=["A","B"],columns=["C"])
# Out:
#                 D
# C             bar       foo
# A     B
# one   A  0.369842  1.285468
#       B -0.584834  0.409710
#       C  0.456271  0.880501
# three A -0.260025       NaN
#       B       NaN -0.952433
#       C -0.162200       NaN
# two   A       NaN  0.061973
#       B -2.552582       NaN
#       C       NaN  0.270670

# %%
rng=pd.date_range("20010102",periods=100,freq="s")
ts=pd.Series(np.random.randint(0,500,len(rng)),index=rng)
ts.head(10)
# Out:
# 2001-01-02 00:00:00    289
# 2001-01-02 00:00:01    186
# 2001-01-02 00:00:02     78
# 2001-01-02 00:00:03    320
# 2001-01-02 00:00:04    341
# 2001-01-02 00:00:05    229
# 2001-01-02 00:00:06    167
# 2001-01-02 00:00:07    445
# 2001-01-02 00:00:08    309
# 2001-01-02 00:00:09    328
# Freq: s, dtype: int32

# %%
print(ts.resample("1Min").sum())
print(ts.groupby(pd.Grouper(freq='min')).sum())
min_range= ts.index.strftime('%Y-%m-%d %H-%M') # type: ignore
ts.groupby(min_range).sum()
# Out:
# 2001-01-02 00:00:00    15876
# 2001-01-02 00:01:00    10189
# Freq: min, dtype: int32
# 2001-01-02 00:00:00    15876
# 2001-01-02 00:01:00    10189
# Freq: min, dtype: int32
# 2001-01-02 00-00    15876
# 2001-01-02 00-01    10189
# dtype: int32

# %%
rng =pd.date_range("01/02/2001 00:00",periods=5,freq= "D")
ts=pd.Series(np.random.randn(len(rng)),rng)
ts
# Out:
# 2001-01-02 00:00:00   -0.043704
# 2001-01-02 00:01:00   -0.040857
# 2001-01-02 00:02:00    0.718658
# 2001-01-02 00:03:00   -0.391903
# 2001-01-02 00:04:00   -0.688882
# Freq: min, dtype: float64

# %%
tz=ts.tz_localize("UTC")
tz
# Out:
# 2001-01-02 00:00:00+00:00    0.160304
# 2001-01-03 00:00:00+00:00   -0.410484
# 2001-01-04 00:00:00+00:00   -0.096419
# 2001-01-05 00:00:00+00:00   -0.259545
# 2001-01-06 00:00:00+00:00    0.160198
# Freq: D, dtype: float64

# %%
tz.tz_convert("US/Eastern")
# Out:
# 2001-01-01 19:00:00-05:00    0.160304
# 2001-01-02 19:00:00-05:00   -0.410484
# 2001-01-03 19:00:00-05:00   -0.096419
# 2001-01-04 19:00:00-05:00   -0.259545
# 2001-01-05 19:00:00-05:00    0.160198
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2001-01-02', '2001-01-03', '2001-01-04', '2001-01-05',
#                '2001-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng+pd.offsets.BusinessDay(5)
#sunday & sat skip
# Out:
# DatetimeIndex(['2001-01-09', '2001-01-10', '2001-01-11', '2001-01-12',
#                '2001-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6],"raw_grade":["a","b","b","a","a","e"]})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"]=df["raw_grade"].astype("category")
# df["grade"]=pd.Series(df["raw_grade"], dtype='category')
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good","good","very bad"]
df["grade"]=df["grade"].cat.rename_categories(new_categories)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
df["grade"]=df["grade"].cat.set_categories(["very bad","bad","medium","good","very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
print(df.groupby("grade",observed=True).size())
print(df.groupby("grade",observed=False).size())
print(df.groupby("grade",observed=False).count())
# print(df.groupby("grade",observed=False).count().iloc[:,[0]])
# Out:
# grade
# very bad     1
# good         2
# very good    3
# dtype: int64
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64
#            id  raw_grade
# grade
# very bad    1          1
# bad         0          0
# medium      0          0
# good        2          2
# very good   3          3

# %%
import matplotlib.pyplot as plt
plt.close("all")
# closes all the open plt figures

# %%
ts=pd.Series(np.random.randn(1000),pd.date_range("02/01/2001",periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(1000,4),columns=["A","B","C","D"])
print(df.head(10))
df=df.cumsum()
plt.figure()
df.plot()
plt.legend(loc="best")
# Out:
#           A         B         C         D
# 0  0.732406 -0.172715 -0.514466  0.085901
# 1 -0.241952 -1.190925  0.798091  0.732903
# 2  0.192811 -1.068832 -0.736957  1.237051
# 3  0.784185  0.741002 -0.083405  0.310920
# 4 -0.062078 -0.536966 -0.192391 -0.855440
# 5 -0.051602  0.238836  1.343363 -1.659449
# 6  2.371658 -0.282585 -1.223501  1.041694
# 7  1.903946 -0.964181  1.690200  0.007631
# 8 -1.447526  0.959282  0.504952  0.640843
# 9  0.203375 -0.426092 -0.616101  0.381872

# %%
df=pd.DataFrame(np.random.randint(0,5,(10,5)), columns= list("ABCDE"))
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  A  B  C  D  E
# 0           0  1  2  3  4  4
# 1           1  4  4  1  4  0
# 2           2  3  2  1  1  4
# 3           3  3  2  1  4  4
# 4           4  4  0  3  0  4
# 5           5  3  4  0  0  4
# 6           6  1  0  2  2  0
# 7           7  0  4  2  1  2
# 8           8  4  2  2  0  0
# 9           9  1  1  4  2  4

# %%
df.to_parquet("foo.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[71], line 2
#       1 import pyarrow, fastparquet
# ----> 2 df.to_parquet("foo.parquet")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parquet.py:478, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 if isinstance(partition_cols, str):
#     477     partition_cols = [partition_cols]
# --> 478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     482 impl.write(
#     483     df,
#     484     path_or_buf,
#    (...)    490     **kwargs,
#     491 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\arrays\arrow\extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined

# %%
df.to_excel('foo.xlsx',sheet_name="sheet1")

# %%
pd.read_excel("foo.xlsx","sheet1",index_col=None,na_values=["NA"])
# Out:
#    Unnamed: 0  1  2  3  4
# 0
# 3           0  3  1  3  4
# 1           1  2  0  0  0
# 3           2  4  2  3  4
# 0           3  2  0  4  0
# 1           4  0  2  3  2
# 3           5  3  4  0  0
# 3           6  1  0  3  2
# 0           7  0  3  1  1
# 3           8  1  3  3  2
# 0           9  2  0  0  3
