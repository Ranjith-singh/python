# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series(5, index=[0,0,3,4,5])
series
# Out:
# 0    5
# 0    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
series = pd.Series({"a":[10,20],"b":np.random.randn(3),"c":30})
series
# Out:
# a                                             [10, 20]
# b    [-0.12712955070684162, -0.7752284221812613, 0....
# c                                                   30
# dtype: object

# %%
series["a"]
# Out:
# [10, 20]

# %%
series.iloc[0]
# Out:
# [10, 20]

# %%
series[:3]
# Out:
# a                                             [10, 20]
# b    [-0.12712955070684162, -0.7752284221812613, 0....
# c                                                   30
# dtype: object

# %%
series.loc[:"c"]
# Out:
# a                                             [10, 20]
# b    [-0.12712955070684162, -0.7752284221812613, 0....
# c                                                   30
# dtype: object

# %%
s=pd.Series(np.random.randn(5),index=["a","b","c","d","e"])
s[s>s.median()]
# Out:
# a    1.237559
# c    0.952884
# dtype: float64

# %%
np.exp(s)
# Out:
# a    3.447190
# b    0.052275
# c    2.593178
# d    0.433456
# e    0.485008
# dtype: float64

# %%
s
# Out:
# a    1.237559
# b   -2.951239
# c    0.952884
# d   -0.835964
# e   -0.723589
# dtype: float64

# %%
s.get("f",5)
# Out:
# 5

# %%
s+s
# Out:
# a    2.475119
# b   -5.902478
# c    1.905768
# d   -1.671928
# e   -1.447178
# dtype: float64

# %%
s*2
# Out:
# a    2.475119
# b   -5.902478
# c    1.905768
# d   -1.671928
# e   -1.447178
# dtype: float64

# %%
s*s
# Out:
# a    1.531553
# b    8.709811
# c    0.907988
# d    0.698836
# e    0.523581
# dtype: float64

# %%
(s.iloc[1:]+s.iloc[:-1]).dropna()
# Out:
# b   -5.902478
# c    1.905768
# d   -1.671928
# dtype: float64

# %%
s=pd.Series(np.random.randn(4),name="something")
s
# Out:
# 0    0.618273
# 1   -0.991033
# 2    0.700118
# 3   -0.653505
# Name: something, dtype: float64

# %%
s.name="differnt"
s
# Out:
# 0    0.618273
# 1   -0.991033
# 2    0.700118
# 3   -0.653505
# Name: differnt, dtype: float64

# %%
s2=s.rename("diff")
s2
# Out:
# 0    0.618273
# 1   -0.991033
# 2    0.700118
# 3   -0.653505
# Name: diff, dtype: float64

# %%
d={
    "one":pd.Series(list(range(1,4)),index=list("abc")),
    "two":pd.Series(list(range(1,5)),index=list("abcd"))
}
df=pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
pd.DataFrame(df, index=list("bad"))
# Out:
#    one  two
# b  2.0    2
# a  1.0    1
# d  NaN    4

# %%
type(df.loc["b","two"])
# Out:
# numpy.int64

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
data = np.zeros((2,), dtype=[("A","i4"),("B","f4"),("C","a10")])
data[:]=[(1,2,"hello"),(2,3.0,"world")]
pd.DataFrame(data)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_12716\3566926892.py:1: DeprecationWarning: Data type alias 'a' was deprecated in NumPy 2.0. Use the 'S' alias instead.
#   data = np.zeros((2,), dtype=[("A","i4"),("B","f4"),("C","a10")])
#    A    B         C
# 0  1  2.0  b'hello'
# 1  2  3.0  b'world'

# %%
data={
        "a":[10,20],
        "b":10}
pd.DataFrame(data)
# Out:
#     a   b
# 0  10  10
# 1  20  10
