# %%
print("5>2");   print(2>5)
# ; Can be used to print multiple statements in the same line
# Out:
# 5>2
# False

# %%
print("hello boss.", end=" ")
print("hello guru")
# Out:
# hello boss hello guru

# %%
print("hello santosh", "hey bro")
print("hello santosh", "hey bro", sep=",")
# Out:
# hello santosh hey bro
# hello santosh,hey bro

# %%
"this is a comment"
# this is a comment
"""this is a also
a comment"""
# last line is printed because of implicit value
# Out:
# 'this is a also\na comment'

# %%
x= 5
x= "ArithmeticError"
print(x)
# items can be assigned multiple times to multiple dtypes
# Out:
# ArithmeticError

# %%
x= str(3)
y= int(x)
z= float(y)
print(x, y, z)
# Out:
# 3 3 3.0

# %%
print(ord('a'))
# Out:
# 97

# %%
# convert str to num
byteEncode= "abb".encode()
print('byteEncode of abb:', byteEncode)
# str to byte encoding
int.from_bytes(byteEncode, 'big')
# Out:
# b'abb'
# 6382178

# %%
x, y, z= "Apple", "Banana", "Cheery"
print(x, y, z)
x= y= z= "Dragon Fruit"
x, y, z
# Multiple Variable Assignment
# Out:
# Apple Banana Cheery
# ('Dragon Fruit', 'Dragon Fruit', 'Dragon Fruit')

# %%
array_list= ['Apple', "banana", "Cherry"]
a, b, c= array_list
print(a, b, c)
# Out:
# Apple banana Cherry

# %%
print("python "+ 'interpreter')
print(5+ 4)
# print(5+ 'interpreter')
# the + only works b/w similar dtype
# Out:
# python interpreter
# 9

# %%
def myFunc():
    global x
    # looks for the var outside the func if not present creates a new one
    x= "5", 5
myFunc()
print(x)
# Out:
# ('5', 5)

# %%
x= 2j
y= range(5)
z= b"hello"
a= bytearray(5)
b= None
print(x, y, z, a, b)
# Out:
# 2j range(0, 5) b'hello' bytearray(b'\x00\x00\x00\x00\x00') None

# %%
x= 35e3
y= 43.2e3
print(x, y)
print(type(x), type(y))
# Out:
# 35000.0 43200.0
# <class 'float'> <class 'float'>

# %%
parents= '"parents"'
x= f"hello john's {parents}"
x
# Out:
# 'hello john\'s "parents"'

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
text= "FBI openUp.."
print(text[:2])
for char in text:
    print(char, end=" ")
print()
print("FBI" in text)
if "Chari" not in text:
    print("yenti gurugaru")
# Out:
# FB
# F B I   o p e n U p . .
# True
# yenti gurugaru

# %%
print(text[-5:-2])
print(text[::-1])
print(text[-5:-2][::-1])
# Out:
# nUp
# ..pUnepo IBF
# pUn

# %%
text= "hello World"
print(text.upper())
print(text.lower())
print(text.capitalize())
text= "  Hello world   "
print(text.split())
print(text.strip())
print(text.replace('l', 'r'))
# Out:
# HELLO WORLD
# hello world
# Hello world
# ['Hello', 'world']
# Hello world
#   Herro worrd

# %%
price= 59
print(f"These shoes are {price} Dollars")
print(f"These shoes are {price:.2f} Dollars")
print(f"These shoes are {price*2} Dollars")
# Out:
# These shoes are 59 Dollars
# These shoes are 59.00 Dollars
# These shoes are 118 Dollars

# %%
print("These are the \"Vikings\"")
print("These are the \\Vikings\\")
print("These are the \nVikings")
# Out:
# These are the "Vikings"
# These are the \Vikings\
# These are the
# Vikings

# %%
text= "Brother"
print(text.center(15))
print(text.count("r"))
print(text.find("r"))
print(text.index("r"))
print(text.rfind("r"))
print(text.rindex("r"))
print(text.expandtabs())
print(text.isalnum())
print(text.ljust(10))
print(",".join(["brother", "house"]))
print("brother".join(["house"]))
# Out:
#     Brother
# 2
# 1
# 1
# 6
# 6
# Brother
# True
# Brother
# brother,house
# house

# %%
print(5>3)
print(" ">"")
print(bool(""))
print(bool("[]"))
print(bool(None))
# Out:
# True
# True
# False
# True
# False

# %%
print(2**3)
print(2*['li','li2'])
print(8//3)
# Out:
# 8
# ['li', 'li2', 'li', 'li2']
# 2

# %%
x= 5
print(x & 3)
print(x | 3)
print(x>>3)
print(x<<3)
print(x:= 3)
# Out:
# 1
# 7
# 0
# 40
# 3

# %%
print(not(x>3))
# print(~(x>3))
# Out:
# True
# -1
# C:\Users\singh\AppData\Local\Temp\ipykernel_13164\3419981605.py:2: DeprecationWarning: Bitwise inversion '~' on bool is deprecated and will be removed in Python 3.16. This returns the bitwise inversion of the underlying int object and is usually not what you expect from negating a bool. Use the 'not' operator for boolean negation or ~int(x) if you really want the bitwise inversion of the underlying int.
#   print(~(x>3))

# %%
x= 5
y= 5
z= x
print(x is z)
print(x is y)
print(x== y)
# Out:
# True
# True
# True

# %%
x= ['apple', 'banana']
y= ['apple', 'banana']
z= x
print(x is z)
print(x is y)
print(x== y)
# Out:
# True
# False
# True

# %%
print('banana' in y)
# Out:
# True

# %%
thisList= ['apple', 'orange', 'banana']
thisList[1:3]= ['kiwi', 'Guava']
print(thisList)
thisList[1:2]= ['kiwi', 'Guava']
print(thisList)
# Out:
# ['apple', 'kiwi', 'Guava']
# ['apple', 'kiwi', 'Guava', 'Guava']

# %%
thisList= ['apple', 'orange', 'banana']
thisList.insert(1, 'Grapes')
print(thisList)
thisList.append("Dragon Fruit")
print(thisList)
thisList.extend(["a", "b"])
print(thisList)
# Out:
# ['apple', 'Grapes', 'orange', 'banana']
# ['apple', 'Grapes', 'orange', 'banana', 'Dragon Fruit']
# ['apple', 'Grapes', 'orange', 'banana', 'Dragon Fruit', 'a', 'b']

# %%
thisList= ['apple', 'orange', 'banana', "Grapes"]
thisList.remove("banana")
print(thisList)
thisList.pop(-1)
print(thisList)
del thisList
# print(thisList)
# List deleted provides an error
thisList= ['apple', 'orange', 'banana', "Grapes"]
thisList.clear()
print(thisList)
# Out:
# ['apple', 'orange', 'Grapes']
# ['apple', 'orange']
# []

# %%
thisList= ['apple', 'orange', 'banana', "Grapes"]
[print(item) for item in thisList]
# Out:
# apple
# orange
# banana
# Grapes
# [None, None, None, None]

# %%
thisList= ['apple', 'orange', 'banana', "Grapes"]
newList= [item for item in thisList if 'e' in item]
print(newList)
# Out:
# ['apple', 'orange', 'Grapes']

# %%
thisList= ['apple', 'orange', 'banana', "Grapes"]
thisList.sort()
print(thisList)
thisList.sort(key= str.lower)
print(thisList)
nums= [10, 5, 7, 2, 3, 11]
def myNumsSort(n):
    return abs(n- 10)
nums.sort(key=myNumsSort)
print(nums)
nums.reverse()
print(nums)
# Out:
# ['Grapes', 'apple', 'banana', 'orange']
# ['apple', 'banana', 'Grapes', 'orange']
# [10, 11, 7, 5, 3, 2]
# [2, 3, 5, 7, 11, 10]

# %%
list1= nums
# the above stmt list1 has only the reference of the nums
# change in value of list1 effects nums

# Creating new List for old list
list1= nums.copy()
list1= nums[:]
list1= list(nums)
list1[1]= 9
print(nums)
print(list1)
# Out:
# [2, 3, 5, 7, 11, 10]
# [2, 9, 5, 7, 11, 10]

# %%
nums= [10, 5, 7, 2, 3, 11]
list2= list1+ nums
print(list2)
list1.extend(nums)
print(list1)
# Out:
# [2, 9, 5, 7, 11, 10, 2, 3, 5, 7, 11, 10, 2, 3, 5, 7, 11, 10, 2, 3, 5, 7, 11, 10, 10, 5, 7, 2, 3, 11]
# [2, 9, 5, 7, 11, 10, 2, 3, 5, 7, 11, 10, 2, 3, 5, 7, 11, 10, 2, 3, 5, 7, 11, 10, 10, 5, 7, 2, 3, 11]
